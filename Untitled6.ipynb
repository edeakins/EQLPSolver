# %%
import pandas as pd
gurFile = pd.read_csv("/mnt/c/Users/edeak/gurobi_times.csv")
import csv

# %%
otherFile = pd.read_csv("/mnt/c/Users/edeak/OC_VS_HiGHS_timings_for_jim_03-8-2021.csv")

# %%
lCnt = 0
gurDict = {}
newGurDict = {}
with open("/mnt/c/Users/edeak/gurobi_times.csv") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        if lCnt:
            gurDict[row[0]] = float(row[1])
        lCnt += 1

# %%
lCnt = 0
with open("/mnt/c/Users/edeak/OC_VS_HiGHS_timings_for_jim_03-8-2021.csv") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter = ',')
    for row in csv_reader:
        if lCnt > 1:
            name = row[0]
            print(gurDict[name])
        lCnt += 1
# Out:
# 0.55112195
# 1.597993135
# 6.555198193
# 0.051367998
# 0.096349955
# 0.000612974
# 0.00050211
# 0.000478983
# 0.000753164
# 0.000803947
# 0.000540018
# 0.000924826
# 0.000929832
# 0.001192093
# 0.00097084
# 0.001910925
# 0.004953861
# 0.005522966
# 0.001819134
# 0.042217016
# 0.084182024
# 0.075647831
# 0.042537928
# 0.309468985
# 0.822381973
# 1.030748129
# 0.307988167
# 6.560740948
# 21.57625294
# 28.83532214
# 0.000575066
# 0.000473022
# 0.000370979
# 0.000729084
# 0.000576973
# 0.000654936
# 0.002123833
# 0.002887011
# 0.002820015
# 0.015136957
# 0.028362036
# 0.031433821
# 0.582946062
# 0.656264067
# 0.805521011
# 0.583769083
# 2.639904022
# 5.774616003
# 8.20609498
# 50.50412202
# 205.945967
# 226.992836
# 0.000448942
# 0.000468969
# 0.000612974
# 0.001279116
# 0.001523972
# 0.00141716
# 0.009941101
# 0.013452053
# 0.012002945
# 0.174834013
# 0.212954044
# 0.286110163
# 0.778695107
# 1.825648785
# 2.584723949
# 0.000967979
# 0.001049995
# 0.000827074
# 0.003296137
# ...
